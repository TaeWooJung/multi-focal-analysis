# %%
import pandas as pd
import numpy as np
import os

# %%
# Source path for the CSV file
PATH_DATA = "/Users/taewoojung/Documents/PhD/Papers/GenomeMedicine/Data/"

# %%
def process_tNGS(targetedDNA, patID):
    columns = ["Sample ID", "Patient ID", "patient_id", "sample_id", "chrom", "pos", "genes", "ref", "alt", "N_DP", "N_VAF", "N_ALT", "T_DP", "T_VAF", "T_ALT",
           "somatic_status", "somatic_p_value", "type"]
    sample_ids = []
    sample_ids_full = []
    refs = []
    alts = []

    targetedDNA["Patient ID"] = "HR-{}".format(patID)

    for _, row in targetedDNA.iterrows():
        sample_id = row["sampleID_y"].split("HR"+patID.split("ID")[1])[1]
        if "MLN" not in row["sampleID_y"]:
            sample_id = "RP" + sample_id

        sample_ids.append(sample_id) 
        sample_ids_full.append("HR_{}_{}".format(patID, sample_id))

        # substitution
        ref = row["VC"].split("_")[-2]
        alt = row["VC"].split("_")[-1]

        if "+" in alt:  # deletion
            alt = ref + alt[1:]
        
        elif "-" in alt:    # insertion
            ref = row["VC"].split("_")[-1]
            alt = row["VC"].split("_")[-2]
            ref = alt + ref[1:]

        refs.append(ref)
        alts.append(alt)

    targetedDNA["sample_id"] = sample_ids
    targetedDNA["Sample ID"] = sample_ids_full
    targetedDNA["ref"] = refs
    targetedDNA["alt"] = alts
    targetedDNA = targetedDNA[columns]

    return targetedDNA

# %%
# Locally advanced cohort
LN_pat = ["ID4", "ID5", "ID6", "ID9", "ID10"]
columns = ["patient_id", "sample_id", "chrom", "pos", "ref", "alt", "N_DP", "N_VAF", "N_ALT", "T_DP", "T_VAF", "T_ALT",
           "somatic_status", "somatic_p_value", "type", "genes"]

patID = LN_pat[0]
targetedDNA = pd.read_csv(os.path.join(PATH_DATA, "tNGS_LN_VarScan2_results/{}_res.csv".format(patID)))
targetedDNA["patient_id"] = patID

targetedDNA = process_tNGS(targetedDNA, patID)

for patID in LN_pat[1:]:
    tmp = pd.read_csv(os.path.join(PATH_DATA, "tNGS_LN_VarScan2_results/{}_res.csv".format(patID)))
    tmp["patient_id"] = patID
    tmp = process_tNGS(tmp, patID)

    targetedDNA = pd.concat([targetedDNA, tmp], ignore_index=True)

# %%
for patID in LN_pat:
    sample_ids = sorted(list(set(targetedDNA[targetedDNA["patient_id"] == patID]["sample_id"].values)))
    MLN_samples = [sample_id for sample_id in sample_ids if "MLN" in sample_id]
    RP_samples = [sample_id for sample_id in sample_ids if "RP" in sample_id]

    overlapping_muts = []

    tmp = targetedDNA[targetedDNA["patient_id"] == patID]

    for i, RP_sample in enumerate(RP_samples):
        overlaps = []

        for j, MLN_sample in enumerate(MLN_samples):
            overlap = list(set(tmp[tmp["sample_id"] == RP_sample]["pos"].values) & set(tmp[tmp["sample_id"] == MLN_sample]["pos"].values))
            overlaps.append(len(overlap))

        overlapping_muts.append(overlaps.copy())

    print("{}:\n\t{}\n\t{}".format(patID, '{} x {}'.format(MLN_samples, RP_samples), overlapping_muts))
# Out:
# ID4:
# 	['MLN1', 'MLN2', 'MLN3'] x ['RP1', 'RP2', 'RP3', 'RP4', 'RP5']
# 	[[6, 1, 2], [4, 4, 3], [7, 2, 2], [3, 3, 2], [3, 1, 1]]
# ID5:
# 	['MLN1', 'MLN2', 'MLN3'] x ['RP1', 'RP2', 'RP3', 'RP4']
# 	[[15, 12, 17], [14, 15, 15], [6, 4, 4], [8, 4, 9]]
# ID6:
# 	['MLN1', 'MLN2', 'MLN3'] x ['RP1', 'RP2', 'RP3', 'RP4']
# 	[[1, 0, 2], [5, 1, 3], [3, 2, 3], [3, 1, 3]]
# ID9:
# 	['MLN1', 'MLN2'] x ['RP1', 'RP3', 'RP4', 'RP5']
# 	[[3, 1], [1, 0], [1, 1], [3, 0]]
# ID10:
# 	['MLN1', 'MLN2'] x ['RP1', 'RP2', 'RP3', 'RP4', 'RP5', 'RP6']
# 	[[1, 1], [1, 1], [2, 1], [5, 1], [2, 1], [3, 2]]

# %%
pos_to_genes = {}

for i, row in targetedDNA.iterrows():
    pos = row["pos"]
    genes = row["genes"]
    if pos not in pos_to_genes:
        pos_to_genes[pos] = genes

# %%
for patID in LN_pat:
    sample_ids = sorted(list(set(targetedDNA[targetedDNA["patient_id"] == patID]["sample_id"].values)))
    MLN_samples = [sample_id for sample_id in sample_ids if "MLN" in sample_id]
    RP_samples = [sample_id for sample_id in sample_ids if "RP" in sample_id]

    overlapping_muts = []

    tmp = targetedDNA[targetedDNA["patient_id"] == patID]

    for i, RP_sample in enumerate(RP_samples):
        overlaps = []

        for j, MLN_sample in enumerate(MLN_samples):
            overlap = list(set(tmp[tmp["sample_id"] == RP_sample]["pos"].values) & set(tmp[tmp["sample_id"] == MLN_sample]["pos"].values))
            overlap = [pos_to_genes[pos] for pos in overlap if pos in pos_to_genes]
            overlaps.append(overlap)

        overlapping_muts.append(overlaps.copy())

    print("{}:\n\t{}\n\t{}".format(patID, '{} x {}'.format(MLN_samples, RP_samples), overlapping_muts))
# Out:
# ID4:
# 	['MLN1', 'MLN2', 'MLN3'] x ['RP1', 'RP2', 'RP3', 'RP4', 'RP5']
# 	[[['PTEN', nan, 'ERG', 'BRCA2', 'GPC6', 'AC100802.3'], ['GPC6'], ['MTMR8', 'GPC6']], [['GPC6', 'GPC6', 'AC100802.3', 'BRCA2'], ['RP11-705C15.5', 'GPC6', 'CDK12', nan], ['GPC6', 'SUSD1', nan]], [['BRCA2', 'PTEN', 'ERG', 'CDK12', 'RB1', 'GPC6', 'BRCA2'], ['GPC6', 'BRCA1'], ['GPC6', 'SUSD1']], [['GPC6', 'PTEN', 'AR'], [nan, 'GPC6', 'RP11-705C15.5'], ['GPC6', 'SUSD1']], [['GPC6', 'BRCA2', 'BRCA2'], ['GPC6'], ['GPC6']]]
# ID5:
# 	['MLN1', 'MLN2', 'MLN3'] x ['RP1', 'RP2', 'RP3', 'RP4']
# 	[[['ATM', 'BRCA2', 'ATM', 'ERG', 'KMT2C', 'GOLPH3L', nan, 'ATM', 'FOXA1', 'ERG', 'SETD2', 'AR', 'BRAF', nan, 'RB1'], ['ATM', 'CDK12', 'ATM', 'ERG', 'KMT2C', 'GOLPH3L', 'FOXA1', 'AR', 'RB1', 'ABCC5', nan, 'RB1'], ['ATM', 'ATM', 'ATM', 'FOXA1', 'KMT2C', 'GOLPH3L', nan, 'FOXA1', 'MSH2', 'ATP10A', 'AR', 'ERG', 'RB1', nan, 'BRAF', 'RB1', 'BRCA1']], [['BRCA2', 'ATM', 'RB1', 'ERG', 'KMT2C', 'GOLPH3L', 'FOXA1', 'SETD2', 'AR', 'RB1', 'BRAF', nan, 'RB1', 'RB1'], ['BRCA2', 'ATM', 'AR', 'ATM', 'BRCA1', 'ERG', 'KMT2C', 'GOLPH3L', 'BRCA2', 'RB1', 'FOXA1', 'AR', 'LTBP1', nan, 'RB1'], ['BRCA2', 'ATM', nan, 'ATM', 'FAM175A', 'PTEN', 'GOLPH3L', 'KMT2C', 'FOXA1', 'AR', nan, 'BRCA1', 'RB1', 'DLX6-AS1', nan]], [['ATM', nan, 'RUNX2', 'RSPH1', 'ATM', 'RB1'], ['RB1', 'RB1', 'RUNX2', 'CDK12'], ['RB1', 'RB1', 'RUNX2', nan]], [['ATM', 'ATM', 'RUNX2', 'GOLPH3L', 'CDK12', 'ERG', 'RB1', 'RB1'], ['RUNX2', 'RB1', 'GOLPH3L', nan], ['ATM', 'ATM', 'RUNX2', 'GOLPH3L', 'ERG', 'ATP10A', 'RB1', 'BRCA1', 'DLX6-AS1']]]
# ID6:
# 	['MLN1', 'MLN2', 'MLN3'] x ['RP1', 'RP2', 'RP3', 'RP4']
# 	[[['ZBTB16'], [], [nan, 'RB1']], [[nan, 'BRCA2', nan, 'ZBTB16', 'RB1'], ['NLGN1'], ['NLGN1', 'BRCA2', 'RB1']], [['ZBTB16', 'RP1-149A16.12', 'RB1'], ['TP53', 'NLGN1'], ['TMPRSS2', 'TP53', 'NLGN1']], [['MSH6', 'ZBTB16', 'RP1-149A16.12'], ['NLGN1'], ['MSH6', nan, 'NLGN1']]]
# ID9:
# 	['MLN1', 'MLN2'] x ['RP1', 'RP3', 'RP4', 'RP5']
# 	[[['BRCA2', 'RALGPS1', 'RAD51B'], [nan]], [['TMPRSS2'], []], [['RALGPS1'], ['RSPH1']], [['AR', 'SYNPO2', 'BRCA2'], []]]
# ID10:
# 	['MLN1', 'MLN2'] x ['RP1', 'RP2', 'RP3', 'RP4', 'RP5', 'RP6']
# 	[[['TP53'], ['TP53']], [['TP53'], ['TP53']], [['ZGPAT', 'TP53'], ['TP53']], [['MAD1L1', 'ZGPAT', 'CDK12', 'TP53', 'BRCA1'], ['TP53']], [['ZGPAT', 'TP53'], ['TP53']], [['ZGPAT', 'ZGPAT', 'TP53'], ['TP53', 'BRCA2']]]

# %%
# Save the processed data
# targetedDNA.loc[:,~targetedDNA.columns.isin(["patient_id", "sample_id"])].to_csv(os.path.join(PATH_DATA, "tNGS_locally_advanced_variant_calling.csv"), index=False)
# pd.Series(list(set(targetedDNA["genes"]))).to_csv(PATH_DATA + "tNGS_gene_panel_locally_advanced.csv")

# %%
# De novo metastatic cohort
targetedDNA = pd.read_csv(PATH_DATA + "M1RP_metastasis_all.tsv", sep="\t")
targetedDNA.index = targetedDNA["GENE"]+"_"+targetedDNA["CHROM"]+"_"+targetedDNA["POSITION"].astype(str)+'_'+targetedDNA["REF"]+"/"+targetedDNA["ALT"]
cols = [x for x in targetedDNA if "cfDNA" not in x and "WBC" not in x and "PB" not in x]
targetedDNA = targetedDNA[cols]

# %%
# pd.Series(list(set(targetedDNA["GENE"]))).to_csv(PATH_DATA + "tNGS_gene_panel_de_novo.csv")

# %%
# patient_id for which we have multiple RP and a matching MLN sample
DN_pat = ["ID3", "ID4", "ID8", "ID23", "ID26", "ID33"]

# %%
for pat in DN_pat:
    patDNA = targetedDNA[[x for x in targetedDNA if pat+"_" in x]]
    patinfo = pd.DataFrame()
    for c in patDNA.columns:
        sample = pd.DataFrame(patDNA[c])
        sample.columns = ["info"]
        sample["sampleID"] = c
        patinfo = pd.concat([patinfo, sample], axis=0)
    patinfo["VAF"] = patinfo["info"].str.split("%", expand=True)[0].astype(float)
    patinfo["DP"] = patinfo["info"].str.split('(', expand=True)[1].str.split(")", expand=True)[0].astype(int)
    patinfo["MQ"] = patinfo["info"].str.split('mq:', expand=True)[1].str.split(",", expand=True)[0]
    patinfo["sign"] = ["*" in x for x in patinfo["info"]]
    patinfo = patinfo.dropna()
    patinfo["DP"] = patinfo["DP"].astype(int)
    patinfo["MQ"] = patinfo["MQ"].astype(int)
    patinfo["ALT"] = (patinfo["VAF"]/100*patinfo["DP"]).round(0)
    patinfo = patinfo[~patinfo.index.isna()]
    #patinfo_filt = patinfo[(patinfo["ALT"]>5)&(patinfo["MQ"]>20)&(patinfo["VAF"]>10)&(patinfo["DP"]>50)]
    patinfo_filt = patinfo[(patinfo["MQ"]>20)&(patinfo["VAF"]>10)&(patinfo["DP"]>50)]
    if pat == "ID3":
        patinfo_filt_ID3 = patinfo_filt
    elif pat=="ID4":
        patinfo_filt_ID4 = patinfo_filt
    elif pat=="ID8":
        patinfo_filt_ID8 = patinfo_filt
    elif pat=="ID23":
        patinfo_filt_ID23 = patinfo_filt
    elif pat=="ID26":
        patinfo_filt_ID26 = patinfo_filt
    elif pat=="ID33":
        patinfo_filt_ID33 = patinfo_filt

# %%
for x in patinfo_filt_ID3.index.value_counts().reset_index()["index"]:
    print(x)
    print(patinfo_filt_ID3.loc[x])
# Out:
# TP53_chr17_7675075_A/G
#                                                     info       sampleID   VAF  \
# TP53_chr17_7675075_A/G  18.9% (665) [mq:42,bq:0,sd:31] *  M1RP_ID3_MLN1  18.9
# TP53_chr17_7675075_A/G  78.6% (425) [mq:42,bq:0,sd:36] *  M1RP_ID3_MLN2  78.6
# TP53_chr17_7675075_A/G  79.8% (501) [mq:42,bq:0,sd:34] *  M1RP_ID3_MLN5  79.8
#
#                          DP  MQ  sign    ALT
# TP53_chr17_7675075_A/G  665  42  True  126.0
# TP53_chr17_7675075_A/G  425  42  True  334.0
# TP53_chr17_7675075_A/G  501  42  True  400.0
# KDM6A_chrX_45053940_G/A
# info        54.7% (329) [mq:37,bq:0,sd:36] *
# sampleID                        M1RP_ID3_RP4
# VAF                                     54.7
# DP                                       329
# MQ                                        37
# sign                                    True
# ALT                                    180.0
# Name: KDM6A_chrX_45053940_G/A, dtype: object

# %%
patinfo_filt_ID4 = patinfo_filt_ID4[patinfo_filt_ID4["sampleID"].isin(['M1RP_ID4_MLN2', 'M1RP_ID4_RP2', 'M1RP_ID4_RP9'])]
for x in patinfo_filt_ID4.index.value_counts().reset_index()["index"]:
    print(x)
    print(patinfo_filt_ID4.loc[x])
# Out:
# FANCE_chr6_35466866_CAA/C
#                                                        info       sampleID  \
# FANCE_chr6_35466866_CAA/C  49.1% (116) [mq:34,bq:0,sd:32] *  M1RP_ID4_MLN2
# FANCE_chr6_35466866_CAA/C  36.5% (386) [mq:37,bq:0,sd:34] *   M1RP_ID4_RP2
# FANCE_chr6_35466866_CAA/C  44.9% (376) [mq:34,bq:0,sd:31] *   M1RP_ID4_RP9
#
#                             VAF   DP  MQ  sign    ALT
# FANCE_chr6_35466866_CAA/C  49.1  116  34  True   57.0
# FANCE_chr6_35466866_CAA/C  36.5  386  37  True  141.0
# FANCE_chr6_35466866_CAA/C  44.9  376  34  True  169.0
# KMT2D_chr12_49049781_GTCAT/G
#                                                            info  \
# KMT2D_chr12_49049781_GTCAT/G   44.5% (694) [mq:39,bq:0,sd:32] *
# KMT2D_chr12_49049781_GTCAT/G   33.5% (713) [mq:39,bq:0,sd:33] *
# KMT2D_chr12_49049781_GTCAT/G  35.9% (1473) [mq:37,bq:0,sd:31] *
#
#                                    sampleID   VAF    DP  MQ  sign    ALT
# KMT2D_chr12_49049781_GTCAT/G  M1RP_ID4_MLN2  44.5   694  39  True  309.0
# KMT2D_chr12_49049781_GTCAT/G   M1RP_ID4_RP2  33.5   713  39  True  239.0
# KMT2D_chr12_49049781_GTCAT/G   M1RP_ID4_RP9  35.9  1473  37  True  529.0
# BRCA2_chr13_32398148_C/T
#                                                       info       sampleID  \
# BRCA2_chr13_32398148_C/T  51.3% (197) [mq:37,bq:0,sd:33] *  M1RP_ID4_MLN2
# BRCA2_chr13_32398148_C/T  30.8% (426) [mq:34,bq:0,sd:34] *   M1RP_ID4_RP2
# BRCA2_chr13_32398148_C/T  38.9% (437) [mq:35,bq:0,sd:32] *   M1RP_ID4_RP9
#
#                            VAF   DP  MQ  sign    ALT
# BRCA2_chr13_32398148_C/T  51.3  197  37  True  101.0
# BRCA2_chr13_32398148_C/T  30.8  426  34  True  131.0
# BRCA2_chr13_32398148_C/T  38.9  437  35  True  170.0
# TP53_chr17_7675115_G/C
#                                                     info       sampleID   VAF  \
# TP53_chr17_7675115_G/C  94.6% (335) [mq:42,bq:0,sd:29] *  M1RP_ID4_MLN2  94.6
# TP53_chr17_7675115_G/C  56.3% (455) [mq:42,bq:0,sd:30] *   M1RP_ID4_RP2  56.3
# TP53_chr17_7675115_G/C  68.9% (881) [mq:42,bq:0,sd:28] *   M1RP_ID4_RP9  68.9
#
#                          DP  MQ  sign    ALT
# TP53_chr17_7675115_G/C  335  42  True  317.0
# TP53_chr17_7675115_G/C  455  42  True  256.0
# TP53_chr17_7675115_G/C  881  42  True  607.0
# CDKN1B_chr12_12720966_TC/T
#                                                       info      sampleID  \
# CDKN1B_chr12_12720966_TC/T  25.4% (142) [mq:36,bq:0,sd:27]  M1RP_ID4_RP2
# CDKN1B_chr12_12720966_TC/T  29.1% (134) [mq:37,bq:0,sd:26]  M1RP_ID4_RP9
#
#                              VAF   DP  MQ   sign   ALT
# CDKN1B_chr12_12720966_TC/T  25.4  142  36  False  36.0
# CDKN1B_chr12_12720966_TC/T  29.1  134  37  False  39.0
# IDH1_chr2_208251422_T/A
# info        22.0% (674) [mq:36,bq:0,sd:26]
# sampleID                      M1RP_ID4_RP9
# VAF                                   22.0
# DP                                     674
# MQ                                      36
# sign                                 False
# ALT                                  148.0
# Name: IDH1_chr2_208251422_T/A, dtype: object
# PALB2_chr16_23630121_A/G
# info        18.2% (729) [mq:36,bq:0,sd:29] *
# sampleID                        M1RP_ID4_RP9
# VAF                                     18.2
# DP                                       729
# MQ                                        36
# sign                                    True
# ALT                                    133.0
# Name: PALB2_chr16_23630121_A/G, dtype: object

# %%
print(len(set(patinfo_filt_ID4.index[patinfo_filt_ID4["sampleID"]=="M1RP_ID4_RP2"]).intersection(
    patinfo_filt_ID4.index[patinfo_filt_ID4["sampleID"]=="M1RP_ID4_MLN2"])), 
      len(set(patinfo_filt_ID4.index[patinfo_filt_ID4["sampleID"]=="M1RP_ID4_RP9"]).intersection(
    patinfo_filt_ID4.index[patinfo_filt_ID4["sampleID"]=="M1RP_ID4_MLN2"])))
# Out:
# 4 4

# %%
patinfo_filt_ID8 = patinfo_filt_ID8[patinfo_filt_ID8['sampleID'].isin(['M1RP_ID8_MLN2', 
                                                                      'M1RP_ID8_MLN3', 'M1RP_ID8_MLN4', 
                                                                      'M1RP_ID8_MLN8', 'M1RP_ID8_MLN9', 
                                                                      'M1RP_ID8_RP2', 'M1RP_ID8_RP1', 
                                                                      'M1RP_ID8_RP4', 'M1RP_ID8_RP7'])]
for x in patinfo_filt_ID8.index.value_counts().reset_index()["index"]:
    print(x)
    print(patinfo_filt_ID8.loc[x])
# Out:
# ATM_chr11_108227318_T/G
#                                                      info       sampleID  \
# ATM_chr11_108227318_T/G  42.0% (317) [mq:39,bq:0,sd:35] *  M1RP_ID8_MLN2
# ATM_chr11_108227318_T/G  36.9% (331) [mq:41,bq:0,sd:31] *  M1RP_ID8_MLN3
# ATM_chr11_108227318_T/G    40.9% (416) [mq:41,bq:0,sd:29]  M1RP_ID8_MLN4
# ATM_chr11_108227318_T/G    24.3% (493) [mq:38,bq:0,sd:29]  M1RP_ID8_MLN8
# ATM_chr11_108227318_T/G  46.4% (420) [mq:40,bq:0,sd:33] *  M1RP_ID8_MLN9
# ATM_chr11_108227318_T/G  33.0% (333) [mq:38,bq:0,sd:31] *   M1RP_ID8_RP1
# ATM_chr11_108227318_T/G    20.0% (360) [mq:38,bq:0,sd:26]   M1RP_ID8_RP2
# ATM_chr11_108227318_T/G  21.5% (427) [mq:39,bq:0,sd:32] *   M1RP_ID8_RP4
# ATM_chr11_108227318_T/G  39.7% (287) [mq:36,bq:0,sd:31] *   M1RP_ID8_RP7
#
#                           VAF   DP  MQ   sign    ALT
# ATM_chr11_108227318_T/G  42.0  317  39   True  133.0
# ATM_chr11_108227318_T/G  36.9  331  41   True  122.0
# ATM_chr11_108227318_T/G  40.9  416  41  False  170.0
# ATM_chr11_108227318_T/G  24.3  493  38  False  120.0
# ATM_chr11_108227318_T/G  46.4  420  40   True  195.0
# ATM_chr11_108227318_T/G  33.0  333  38   True  110.0
# ATM_chr11_108227318_T/G  20.0  360  38  False   72.0
# ATM_chr11_108227318_T/G  21.5  427  39   True   92.0
# ATM_chr11_108227318_T/G  39.7  287  36   True  114.0
# TBCD_chr17_82802000_C/T
#                                                      info       sampleID  \
# TBCD_chr17_82802000_C/T    43.1% (269) [mq:30,bq:0,sd:25]  M1RP_ID8_MLN3
# TBCD_chr17_82802000_C/T    47.0% (413) [mq:32,bq:0,sd:26]  M1RP_ID8_MLN4
# TBCD_chr17_82802000_C/T    46.1% (401) [mq:33,bq:0,sd:24]  M1RP_ID8_MLN9
# TBCD_chr17_82802000_C/T    19.6% (194) [mq:33,bq:0,sd:23]   M1RP_ID8_RP2
# TBCD_chr17_82802000_C/T  14.2% (339) [mq:30,bq:0,sd:35] *   M1RP_ID8_RP7
#
#                           VAF   DP  MQ   sign    ALT
# TBCD_chr17_82802000_C/T  43.1  269  30  False  116.0
# TBCD_chr17_82802000_C/T  47.0  413  32  False  194.0
# TBCD_chr17_82802000_C/T  46.1  401  33  False  185.0
# TBCD_chr17_82802000_C/T  19.6  194  33  False   38.0
# TBCD_chr17_82802000_C/T  14.2  339  30   True   48.0
# AKT1_chr14_104780108_A/C
#                                                        info       sampleID  \
# AKT1_chr14_104780108_A/C  42.0% (1035) [mq:42,bq:0,sd:28] *  M1RP_ID8_MLN3
# AKT1_chr14_104780108_A/C  46.3% (1244) [mq:42,bq:0,sd:29] *  M1RP_ID8_MLN4
# AKT1_chr14_104780108_A/C  47.6% (1971) [mq:41,bq:0,sd:29] *  M1RP_ID8_MLN9
# AKT1_chr14_104780108_A/C   28.2% (714) [mq:42,bq:0,sd:30] *   M1RP_ID8_RP2
# AKT1_chr14_104780108_A/C  15.8% (1203) [mq:41,bq:0,sd:30] *   M1RP_ID8_RP7
#
#                            VAF    DP  MQ  sign    ALT
# AKT1_chr14_104780108_A/C  42.0  1035  42  True  435.0
# AKT1_chr14_104780108_A/C  46.3  1244  42  True  576.0
# AKT1_chr14_104780108_A/C  47.6  1971  41  True  938.0
# AKT1_chr14_104780108_A/C  28.2   714  42  True  201.0
# AKT1_chr14_104780108_A/C  15.8  1203  41  True  190.0
# ZNF276_chr16_89738073_C/A
#                                                         info       sampleID  \
# ZNF276_chr16_89738073_C/A  35.1% (1403) [mq:41,bq:0,sd:29] *  M1RP_ID8_MLN3
# ZNF276_chr16_89738073_C/A  43.8% (1700) [mq:42,bq:0,sd:28] *  M1RP_ID8_MLN4
# ZNF276_chr16_89738073_C/A  45.4% (2306) [mq:42,bq:0,sd:29] *  M1RP_ID8_MLN9
# ZNF276_chr16_89738073_C/A  19.8% (1076) [mq:41,bq:0,sd:28] *   M1RP_ID8_RP2
# ZNF276_chr16_89738073_C/A  13.8% (1251) [mq:41,bq:0,sd:27] *   M1RP_ID8_RP7
#
#                             VAF    DP  MQ  sign     ALT
# ZNF276_chr16_89738073_C/A  35.1  1403  41  True   492.0
# ZNF276_chr16_89738073_C/A  43.8  1700  42  True   745.0
# ZNF276_chr16_89738073_C/A  45.4  2306  42  True  1047.0
# ZNF276_chr16_89738073_C/A  19.8  1076  41  True   213.0
# ZNF276_chr16_89738073_C/A  13.8  1251  41  True   173.0
# ZFHX3_chr16_72957449_C/T
#                                                        info       sampleID  \
# ZFHX3_chr16_72957449_C/T  36.0% (1840) [mq:42,bq:0,sd:31] *  M1RP_ID8_MLN3
# ZFHX3_chr16_72957449_C/T  43.0% (2232) [mq:41,bq:0,sd:33] *  M1RP_ID8_MLN4
# ZFHX3_chr16_72957449_C/T  42.8% (2778) [mq:42,bq:0,sd:30] *  M1RP_ID8_MLN9
# ZFHX3_chr16_72957449_C/T  34.4% (1089) [mq:42,bq:0,sd:28] *   M1RP_ID8_RP2
# ZFHX3_chr16_72957449_C/T  20.9% (1142) [mq:42,bq:0,sd:32] *   M1RP_ID8_RP7
#
#                            VAF    DP  MQ  sign     ALT
# ZFHX3_chr16_72957449_C/T  36.0  1840  42  True   662.0
# ZFHX3_chr16_72957449_C/T  43.0  2232  41  True   960.0
# ZFHX3_chr16_72957449_C/T  42.8  2778  42  True  1189.0
# ZFHX3_chr16_72957449_C/T  34.4  1089  42  True   375.0
# ZFHX3_chr16_72957449_C/T  20.9  1142  42  True   239.0
# ZFHX3_chr16_72788190_C/T
#                                                        info       sampleID  \
# ZFHX3_chr16_72788190_C/T  34.2% (1025) [mq:41,bq:0,sd:30] *  M1RP_ID8_MLN3
# ZFHX3_chr16_72788190_C/T  41.4% (1182) [mq:41,bq:0,sd:30] *  M1RP_ID8_MLN4
# ZFHX3_chr16_72788190_C/T    45.8% (1442) [mq:41,bq:0,sd:29]  M1RP_ID8_MLN9
# ZFHX3_chr16_72788190_C/T     29.3% (673) [mq:41,bq:0,sd:26]   M1RP_ID8_RP2
# ZFHX3_chr16_72788190_C/T     19.6% (685) [mq:42,bq:0,sd:28]   M1RP_ID8_RP7
#
#                            VAF    DP  MQ   sign    ALT
# ZFHX3_chr16_72788190_C/T  34.2  1025  41   True  351.0
# ZFHX3_chr16_72788190_C/T  41.4  1182  41   True  489.0
# ZFHX3_chr16_72788190_C/T  45.8  1442  41  False  660.0
# ZFHX3_chr16_72788190_C/T  29.3   673  41  False  197.0
# ZFHX3_chr16_72788190_C/T  19.6   685  42  False  134.0
# MDM4_chr1_204551054_G/GT
#                                                       info       sampleID  \
# MDM4_chr1_204551054_G/GT  25.1% (187) [mq:38,bq:0,sd:32] *  M1RP_ID8_MLN3
# MDM4_chr1_204551054_G/GT  37.9% (198) [mq:39,bq:0,sd:36] *  M1RP_ID8_MLN4
# MDM4_chr1_204551054_G/GT  32.1% (262) [mq:38,bq:0,sd:34] *  M1RP_ID8_MLN9
# MDM4_chr1_204551054_G/GT  15.6% (231) [mq:37,bq:0,sd:31] *   M1RP_ID8_RP2
# MDM4_chr1_204551054_G/GT    12.4% (193) [mq:40,bq:0,sd:28]   M1RP_ID8_RP7
#
#                            VAF   DP  MQ   sign   ALT
# MDM4_chr1_204551054_G/GT  25.1  187  38   True  47.0
# MDM4_chr1_204551054_G/GT  37.9  198  39   True  75.0
# MDM4_chr1_204551054_G/GT  32.1  262  38   True  84.0
# MDM4_chr1_204551054_G/GT  15.6  231  37   True  36.0
# MDM4_chr1_204551054_G/GT  12.4  193  40  False  24.0
# CTNNB1_chr3_41224633_A/G
#                                                       info       sampleID  \
# CTNNB1_chr3_41224633_A/G  38.5% (660) [mq:38,bq:0,sd:30] *  M1RP_ID8_MLN3
# CTNNB1_chr3_41224633_A/G  43.1% (596) [mq:38,bq:0,sd:27] *  M1RP_ID8_MLN4
# CTNNB1_chr3_41224633_A/G  43.5% (673) [mq:38,bq:0,sd:30] *  M1RP_ID8_MLN9
# CTNNB1_chr3_41224633_A/G  18.2% (751) [mq:38,bq:0,sd:29] *   M1RP_ID8_RP2
# CTNNB1_chr3_41224633_A/G  13.1% (435) [mq:37,bq:0,sd:25] *   M1RP_ID8_RP7
#
#                            VAF   DP  MQ  sign    ALT
# CTNNB1_chr3_41224633_A/G  38.5  660  38  True  254.0
# CTNNB1_chr3_41224633_A/G  43.1  596  38  True  257.0
# CTNNB1_chr3_41224633_A/G  43.5  673  38  True  293.0
# CTNNB1_chr3_41224633_A/G  18.2  751  38  True  137.0
# CTNNB1_chr3_41224633_A/G  13.1  435  37  True   57.0
# ZFP64_chr20_52105727_G/A
#                                                       info       sampleID  \
# ZFP64_chr20_52105727_G/A  23.2% (125) [mq:40,bq:0,sd:31] *  M1RP_ID8_MLN3
# ZFP64_chr20_52105727_G/A  33.8% (145) [mq:42,bq:0,sd:34] *  M1RP_ID8_MLN4
# ZFP64_chr20_52105727_G/A  37.0% (227) [mq:42,bq:0,sd:40] *  M1RP_ID8_MLN9
# ZFP64_chr20_52105727_G/A   15.2% (66) [mq:42,bq:0,sd:41] *   M1RP_ID8_RP2
# ZFP64_chr20_52105727_G/A    10.4% (125) [mq:42,bq:0,sd:28]   M1RP_ID8_RP7
#
#                            VAF   DP  MQ   sign   ALT
# ZFP64_chr20_52105727_G/A  23.2  125  40   True  29.0
# ZFP64_chr20_52105727_G/A  33.8  145  42   True  49.0
# ZFP64_chr20_52105727_G/A  37.0  227  42   True  84.0
# ZFP64_chr20_52105727_G/A  15.2   66  42   True  10.0
# ZFP64_chr20_52105727_G/A  10.4  125  42  False  13.0
# CLU_chr8_27598600_G/A
#                                                    info       sampleID   VAF  \
# CLU_chr8_27598600_G/A    59.2% (476) [mq:40,bq:0,sd:29]  M1RP_ID8_MLN3  59.2
# CLU_chr8_27598600_G/A    82.7% (416) [mq:39,bq:0,sd:29]  M1RP_ID8_MLN4  82.7
# CLU_chr8_27598600_G/A    88.2% (457) [mq:39,bq:0,sd:29]  M1RP_ID8_MLN9  88.2
# CLU_chr8_27598600_G/A    34.7% (527) [mq:39,bq:0,sd:29]   M1RP_ID8_RP2  34.7
# CLU_chr8_27598600_G/A  24.7% (417) [mq:39,bq:0,sd:32] *   M1RP_ID8_RP7  24.7
#
#                         DP  MQ   sign    ALT
# CLU_chr8_27598600_G/A  476  40  False  282.0
# CLU_chr8_27598600_G/A  416  39  False  344.0
# CLU_chr8_27598600_G/A  457  39  False  403.0
# CLU_chr8_27598600_G/A  527  39  False  183.0
# CLU_chr8_27598600_G/A  417  39   True  103.0
# FANCG_chr9_35076845_T/C
#                                                      info       sampleID  \
# FANCG_chr9_35076845_T/C  37.1% (520) [mq:42,bq:0,sd:27] *  M1RP_ID8_MLN3
# FANCG_chr9_35076845_T/C  47.2% (595) [mq:40,bq:0,sd:29] *  M1RP_ID8_MLN4
# FANCG_chr9_35076845_T/C  51.5% (781) [mq:41,bq:0,sd:29] *  M1RP_ID8_MLN9
# FANCG_chr9_35076845_T/C  18.9% (529) [mq:41,bq:0,sd:27] *   M1RP_ID8_RP2
# FANCG_chr9_35076845_T/C  17.5% (406) [mq:42,bq:0,sd:32] *   M1RP_ID8_RP7
#
#                           VAF   DP  MQ  sign    ALT
# FANCG_chr9_35076845_T/C  37.1  520  42  True  193.0
# FANCG_chr9_35076845_T/C  47.2  595  40  True  281.0
# FANCG_chr9_35076845_T/C  51.5  781  41  True  402.0
# FANCG_chr9_35076845_T/C  18.9  529  41  True  100.0
# FANCG_chr9_35076845_T/C  17.5  406  42  True   71.0
# FOXA1_chr14_37590764_T/C
#                                                       info       sampleID  \
# FOXA1_chr14_37590764_T/C    42.4% (453) [mq:38,bq:0,sd:29]  M1RP_ID8_MLN3
# FOXA1_chr14_37590764_T/C  40.5% (499) [mq:39,bq:0,sd:30] *  M1RP_ID8_MLN4
# FOXA1_chr14_37590764_T/C    43.2% (542) [mq:39,bq:0,sd:28]  M1RP_ID8_MLN9
# FOXA1_chr14_37590764_T/C  26.7% (614) [mq:39,bq:0,sd:30] *   M1RP_ID8_RP2
# FOXA1_chr14_37590764_T/C    17.3% (388) [mq:37,bq:0,sd:29]   M1RP_ID8_RP7
#
#                            VAF   DP  MQ   sign    ALT
# FOXA1_chr14_37590764_T/C  42.4  453  38  False  192.0
# FOXA1_chr14_37590764_T/C  40.5  499  39   True  202.0
# FOXA1_chr14_37590764_T/C  43.2  542  39  False  234.0
# FOXA1_chr14_37590764_T/C  26.7  614  39   True  164.0
# FOXA1_chr14_37590764_T/C  17.3  388  37  False   67.0
# AKT1_chr14_104774423_A/G
#                                                        info       sampleID  \
# AKT1_chr14_104774423_A/G  41.6% (1251) [mq:41,bq:0,sd:30] *  M1RP_ID8_MLN3
# AKT1_chr14_104774423_A/G    46.6% (1541) [mq:41,bq:0,sd:29]  M1RP_ID8_MLN4
# AKT1_chr14_104774423_A/G  44.3% (2272) [mq:41,bq:0,sd:30] *  M1RP_ID8_MLN9
# AKT1_chr14_104774423_A/G  28.6% (1007) [mq:40,bq:0,sd:30] *   M1RP_ID8_RP2
# AKT1_chr14_104774423_A/G    12.9% (1427) [mq:41,bq:0,sd:28]   M1RP_ID8_RP7
#
#                            VAF    DP  MQ   sign     ALT
# AKT1_chr14_104774423_A/G  41.6  1251  41   True   520.0
# AKT1_chr14_104774423_A/G  46.6  1541  41  False   718.0
# AKT1_chr14_104774423_A/G  44.3  2272  41   True  1006.0
# AKT1_chr14_104774423_A/G  28.6  1007  40   True   288.0
# AKT1_chr14_104774423_A/G  12.9  1427  41  False   184.0
# RUNX1_chr21_34788645_A/G
#                                                     info       sampleID   VAF  \
# RUNX1_chr21_34788645_A/G  20.5% (541) [mq:36,bq:0,sd:28]  M1RP_ID8_MLN8  20.5
# RUNX1_chr21_34788645_A/G  29.2% (319) [mq:39,bq:0,sd:28]   M1RP_ID8_RP1  29.2
# RUNX1_chr21_34788645_A/G  22.4% (557) [mq:34,bq:0,sd:27]   M1RP_ID8_RP4  22.4
# RUNX1_chr21_34788645_A/G  18.7% (315) [mq:38,bq:0,sd:29]   M1RP_ID8_RP7  18.7
#
#                            DP  MQ   sign    ALT
# RUNX1_chr21_34788645_A/G  541  36  False  111.0
# RUNX1_chr21_34788645_A/G  319  39  False   93.0
# RUNX1_chr21_34788645_A/G  557  34  False  125.0
# RUNX1_chr21_34788645_A/G  315  38  False   59.0
# ZFHX3_chr16_72798676_CG/C
#                                                        info       sampleID  \
# ZFHX3_chr16_72798676_CG/C  35.7% (269) [mq:38,bq:0,sd:31] *  M1RP_ID8_MLN8
# ZFHX3_chr16_72798676_CG/C  19.8% (247) [mq:39,bq:0,sd:29] *   M1RP_ID8_RP1
# ZFHX3_chr16_72798676_CG/C  33.8% (402) [mq:40,bq:0,sd:28] *   M1RP_ID8_RP4
# ZFHX3_chr16_72798676_CG/C  26.8% (153) [mq:36,bq:0,sd:31] *   M1RP_ID8_RP7
#
#                             VAF   DP  MQ  sign    ALT
# ZFHX3_chr16_72798676_CG/C  35.7  269  38  True   96.0
# ZFHX3_chr16_72798676_CG/C  19.8  247  39  True   49.0
# ZFHX3_chr16_72798676_CG/C  33.8  402  40  True  136.0
# ZFHX3_chr16_72798676_CG/C  26.8  153  36  True   41.0
# PALB2_chr16_23629979_T/C
#                                                       info       sampleID  \
# PALB2_chr16_23629979_T/C    35.6% (581) [mq:40,bq:0,sd:25]  M1RP_ID8_MLN3
# PALB2_chr16_23629979_T/C  41.9% (602) [mq:40,bq:0,sd:30] *  M1RP_ID8_MLN4
# PALB2_chr16_23629979_T/C    42.1% (605) [mq:40,bq:0,sd:27]  M1RP_ID8_MLN9
#
#                            VAF   DP  MQ   sign    ALT
# PALB2_chr16_23629979_T/C  35.6  581  40  False  207.0
# PALB2_chr16_23629979_T/C  41.9  602  40   True  252.0
# PALB2_chr16_23629979_T/C  42.1  605  40  False  255.0
# MET_chr7_116797065_A/G
#                                                     info       sampleID   VAF  \
# MET_chr7_116797065_A/G  35.0% (317) [mq:38,bq:0,sd:30] *  M1RP_ID8_MLN3  35.0
# MET_chr7_116797065_A/G    42.5% (362) [mq:36,bq:0,sd:29]  M1RP_ID8_MLN4  42.5
# MET_chr7_116797065_A/G    43.3% (379) [mq:38,bq:0,sd:28]  M1RP_ID8_MLN9  43.3
#
#                          DP  MQ   sign    ALT
# MET_chr7_116797065_A/G  317  38   True  111.0
# MET_chr7_116797065_A/G  362  36  False  154.0
# MET_chr7_116797065_A/G  379  38  False  164.0
# CDKN2A_chr9_21970785_G/A
#                                                        info      sampleID  \
# CDKN2A_chr9_21970785_G/A  26.1% (1176) [mq:42,bq:0,sd:30] *  M1RP_ID8_RP2
# CDKN2A_chr9_21970785_G/A  12.8% (1479) [mq:42,bq:0,sd:31] *  M1RP_ID8_RP7
#
#                            VAF    DP  MQ  sign    ALT
# CDKN2A_chr9_21970785_G/A  26.1  1176  42  True  307.0
# CDKN2A_chr9_21970785_G/A  12.8  1479  42  True  189.0
# CDK6_chr7_92605511_G/A
#                                                     info      sampleID   VAF  \
# CDK6_chr7_92605511_G/A    17.4% (621) [mq:36,bq:0,sd:26]  M1RP_ID8_RP2  17.4
# CDK6_chr7_92605511_G/A  12.9% (348) [mq:38,bq:0,sd:32] *  M1RP_ID8_RP7  12.9
#
#                          DP  MQ   sign    ALT
# CDK6_chr7_92605511_G/A  621  36  False  108.0
# CDK6_chr7_92605511_G/A  348  38   True   45.0
# FOXA1_chr14_37592287_T/C
#                                                        info       sampleID  \
# FOXA1_chr14_37592287_T/C   25.4% (985) [mq:38,bq:0,sd:31] *  M1RP_ID8_MLN8
# FOXA1_chr14_37592287_T/C  21.7% (1500) [mq:39,bq:0,sd:29] *   M1RP_ID8_RP7
#
#                            VAF    DP  MQ  sign    ALT
# FOXA1_chr14_37592287_T/C  25.4   985  38  True  250.0
# FOXA1_chr14_37592287_T/C  21.7  1500  39  True  326.0
# ERG_chr21_38395618_T/C
#                                                     info       sampleID   VAF  \
# ERG_chr21_38395618_T/C    32.6% (184) [mq:41,bq:0,sd:24]  M1RP_ID8_MLN8  32.6
# ERG_chr21_38395618_T/C  20.8% (120) [mq:41,bq:0,sd:32] *   M1RP_ID8_RP7  20.8
#
#                          DP  MQ   sign   ALT
# ERG_chr21_38395618_T/C  184  41  False  60.0
# ERG_chr21_38395618_T/C  120  41   True  25.0
# TP53_chr17_7673803_G/A
#                                                      info       sampleID  \
# TP53_chr17_7673803_G/A   24.5% (982) [mq:40,bq:0,sd:29] *  M1RP_ID8_MLN3
# TP53_chr17_7673803_G/A  41.9% (1324) [mq:41,bq:0,sd:27] *  M1RP_ID8_MLN9
#
#                          VAF    DP  MQ  sign    ALT
# TP53_chr17_7673803_G/A  24.5   982  40  True  241.0
# TP53_chr17_7673803_G/A  41.9  1324  41  True  555.0
# TP53_chr17_7670685_G/A
#                                                      info       sampleID  \
# TP53_chr17_7670685_G/A   25.9% (796) [mq:42,bq:0,sd:30] *  M1RP_ID8_MLN3
# TP53_chr17_7670685_G/A  42.9% (1176) [mq:41,bq:0,sd:31] *  M1RP_ID8_MLN9
#
#                          VAF    DP  MQ  sign    ALT
# TP53_chr17_7670685_G/A  25.9   796  42  True  206.0
# TP53_chr17_7670685_G/A  42.9  1176  41  True  505.0
# FOXP1_chr3_70958551_T/C
#                                                      info      sampleID   VAF  \
# FOXP1_chr3_70958551_T/C  18.9% (370) [mq:36,bq:0,sd:32] *  M1RP_ID8_RP2  18.9
# FOXP1_chr3_70958551_T/C    12.5% (160) [mq:36,bq:0,sd:29]  M1RP_ID8_RP7  12.5
#
#                           DP  MQ   sign   ALT
# FOXP1_chr3_70958551_T/C  370  36   True  70.0
# FOXP1_chr3_70958551_T/C  160  36  False  20.0
# FANCA_chr16_89810530_T/C
#                                                      info      sampleID   VAF  \
# FANCA_chr16_89810530_T/C   24.6% (167) [mq:41,bq:0,sd:23]  M1RP_ID8_RP2  24.6
# FANCA_chr16_89810530_T/C  18.8% (85) [mq:38,bq:0,sd:36] *  M1RP_ID8_RP7  18.8
#
#                            DP  MQ   sign   ALT
# FANCA_chr16_89810530_T/C  167  41  False  41.0
# FANCA_chr16_89810530_T/C   85  38   True  16.0
# RNF43_chr17_58416896_A/G
#                                                       info      sampleID  \
# RNF43_chr17_58416896_A/G    19.1% (703) [mq:36,bq:0,sd:27]  M1RP_ID8_RP2
# RNF43_chr17_58416896_A/G  10.7% (354) [mq:39,bq:0,sd:30] *  M1RP_ID8_RP7
#
#                            VAF   DP  MQ   sign    ALT
# RNF43_chr17_58416896_A/G  19.1  703  36  False  134.0
# RNF43_chr17_58416896_A/G  10.7  354  39   True   38.0
# MLH1_chr3_37050776_A/G
#                                                     info      sampleID   VAF  \
# MLH1_chr3_37050776_A/G  18.9% (528) [mq:39,bq:0,sd:31] *  M1RP_ID8_RP2  18.9
# MLH1_chr3_37050776_A/G  13.2% (363) [mq:37,bq:0,sd:33] *  M1RP_ID8_RP7  13.2
#
#                          DP  MQ  sign    ALT
# MLH1_chr3_37050776_A/G  528  39  True  100.0
# MLH1_chr3_37050776_A/G  363  37  True   48.0
# RB1_chr13_48445260_A/G
# info        11.5% (209) [mq:38,bq:0,sd:39] *
# sampleID                        M1RP_ID8_RP2
# VAF                                     11.5
# DP                                       209
# MQ                                        38
# sign                                    True
# ALT                                     24.0
# Name: RB1_chr13_48445260_A/G, dtype: object
# EIF2AK1_chr7_6046999_A/G
# info        11.8% (271) [mq:35,bq:0,sd:34] *
# sampleID                        M1RP_ID8_RP2
# VAF                                     11.8
# DP                                       271
# MQ                                        35
# sign                                    True
# ALT                                     32.0
# Name: EIF2AK1_chr7_6046999_A/G, dtype: object
# FANCA_chr16_89762114_C/T
# info        17.6% (51) [mq:42,bq:0,sd:21]
# sampleID                     M1RP_ID8_RP2
# VAF                                  17.6
# DP                                     51
# MQ                                     42
# sign                                False
# ALT                                   9.0
# Name: FANCA_chr16_89762114_C/T, dtype: object
# GNAS_chr20_58909366_G/A
# info        20.2% (608) [mq:40,bq:0,sd:28] *
# sampleID                        M1RP_ID8_RP2
# VAF                                     20.2
# DP                                       608
# MQ                                        40
# sign                                    True
# ALT                                    123.0
# Name: GNAS_chr20_58909366_G/A, dtype: object
# APC_chr5_112707585_C/CG
# info        15.4% (1528) [mq:41,bq:0,sd:30] *
# sampleID                         M1RP_ID8_RP2
# VAF                                      15.4
# DP                                       1528
# MQ                                         41
# sign                                     True
# ALT                                     235.0
# Name: APC_chr5_112707585_C/CG, dtype: object
# KMT2C_chr7_152148296_C/T
# info        41.5% (1012) [mq:39,bq:0,sd:32] *
# sampleID                        M1RP_ID8_MLN2
# VAF                                      41.5
# DP                                       1012
# MQ                                         39
# sign                                     True
# ALT                                     420.0
# Name: KMT2C_chr7_152148296_C/T, dtype: object
# MDM4_chr1_204550211_C/T
# info        14.5% (179) [mq:35,bq:0,sd:33] *
# sampleID                        M1RP_ID8_RP2
# VAF                                     14.5
# DP                                       179
# MQ                                        35
# sign                                    True
# ALT                                     26.0
# Name: MDM4_chr1_204550211_C/T, dtype: object
# RUNX1_chr21_34833401_G/A
# info        45.0% (713) [mq:41,bq:0,sd:33] *
# sampleID                       M1RP_ID8_MLN4
# VAF                                     45.0
# DP                                       713
# MQ                                        41
# sign                                    True
# ALT                                    321.0
# Name: RUNX1_chr21_34833401_G/A, dtype: object
# APC_chr5_112792450_G/A
# info        31.6% (430) [mq:37,bq:0,sd:32] *
# sampleID                       M1RP_ID8_MLN4
# VAF                                     31.6
# DP                                       430
# MQ                                        37
# sign                                    True
# ALT                                    136.0
# Name: APC_chr5_112792450_G/A, dtype: object
# KMT2C_chr7_152157914_CAG/C
# info        36.5% (397) [mq:37,bq:0,sd:36] *
# sampleID                       M1RP_ID8_MLN2
# VAF                                     36.5
# DP                                       397
# MQ                                        37
# sign                                    True
# ALT                                    145.0
# Name: KMT2C_chr7_152157914_CAG/C, dtype: object
# TP53_chr17_7675139_C/T
# info        57.8% (1362) [mq:42,bq:0,sd:30] *
# sampleID                        M1RP_ID8_MLN2
# VAF                                      57.8
# DP                                       1362
# MQ                                         42
# sign                                     True
# ALT                                     787.0
# Name: TP53_chr17_7675139_C/T, dtype: object
# IDH2_chr15_90084143_TA/T
# info        43.1% (1256) [mq:41,bq:0,sd:30] *
# sampleID                        M1RP_ID8_MLN2
# VAF                                      43.1
# DP                                       1256
# MQ                                         41
# sign                                     True
# ALT                                     541.0
# Name: IDH2_chr15_90084143_TA/T, dtype: object
# RB1_chr13_48465271_C/T
# info        45.0% (605) [mq:37,bq:0,sd:27] *
# sampleID                       M1RP_ID8_MLN2
# VAF                                     45.0
# DP                                       605
# MQ                                        37
# sign                                    True
# ALT                                    272.0
# Name: RB1_chr13_48465271_C/T, dtype: object
# ATM_chr11_108248961_A/G
# info        46.8% (280) [mq:35,bq:0,sd:32] *
# sampleID                       M1RP_ID8_MLN2
# VAF                                     46.8
# DP                                       280
# MQ                                        35
# sign                                    True
# ALT                                    131.0
# Name: ATM_chr11_108248961_A/G, dtype: object
# KMT2C_chr7_152250972_CA/C
# info        45.0% (327) [mq:39,bq:0,sd:30] *
# sampleID                       M1RP_ID8_MLN2
# VAF                                     45.0
# DP                                       327
# MQ                                        39
# sign                                    True
# ALT                                    147.0
# Name: KMT2C_chr7_152250972_CA/C, dtype: object
# FOXP1_chr3_70970777_T/C
# info        28.6% (658) [mq:37,bq:0,sd:27] *
# sampleID                        M1RP_ID8_RP4
# VAF                                     28.6
# DP                                       658
# MQ                                        37
# sign                                    True
# ALT                                    188.0
# Name: FOXP1_chr3_70970777_T/C, dtype: object

# %%
print(len(set(patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_RP1"]).intersection(
    patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_MLN2"])), 
      len(set(patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_RP2"]).intersection(
    patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_MLN2"])),
     len(set(patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_RP4"]).intersection(
    patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_MLN2"])),
     len(set(patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_RP7"]).intersection(
    patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_MLN2"])))

print(len(set(patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_RP1"]).intersection(
    patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_MLN3"])), 
      len(set(patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_RP2"]).intersection(
    patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_MLN3"])),
     len(set(patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_RP4"]).intersection(
    patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_MLN3"])),
     len(set(patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_RP7"]).intersection(
    patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_MLN3"])))

print(len(set(patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_RP1"]).intersection(
    patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_MLN4"])), 
      len(set(patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_RP2"]).intersection(
    patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_MLN4"])),
     len(set(patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_RP4"]).intersection(
    patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_MLN4"])),
     len(set(patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_RP7"]).intersection(
    patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_MLN4"])))

print(len(set(patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_RP1"]).intersection(
    patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_MLN8"])), 
      len(set(patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_RP2"]).intersection(
    patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_MLN8"])),
     len(set(patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_RP4"]).intersection(
    patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_MLN8"])),
     len(set(patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_RP7"]).intersection(
    patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_MLN8"])))

print(len(set(patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_RP1"]).intersection(
    patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_MLN9"])), 
      len(set(patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_RP2"]).intersection(
    patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_MLN9"])),
     len(set(patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_RP4"]).intersection(
    patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_MLN9"])),
     len(set(patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_RP7"]).intersection(
    patinfo_filt_ID8.index[patinfo_filt_ID8["sampleID"]=="M1RP_ID8_MLN9"])))
# Out:
# 1 1 1 1
# 1 13 1 13
# 1 13 1 13
# 3 1 3 5
# 1 13 1 13

# %%
for x in patinfo_filt_ID23.index.value_counts().reset_index()["index"]:
    print(x)
    print(patinfo_filt_ID23.loc[x])
# Out:
# RUNX1_chr21_34892926_G/A
#                                                       info        sampleID  \
# RUNX1_chr21_34892926_G/A    25.4% (138) [mq:28,bq:0,sd:34]  M1RP_ID23_RP14
# RUNX1_chr21_34892926_G/A    36.2% (489) [mq:40,bq:0,sd:26]   M1RP_ID23_RP1
# RUNX1_chr21_34892926_G/A  31.2% (349) [mq:38,bq:0,sd:34] *   M1RP_ID23_RP6
# RUNX1_chr21_34892926_G/A  26.3% (433) [mq:38,bq:0,sd:31] *   M1RP_ID23_RP7
# RUNX1_chr21_34892926_G/A  32.9% (277) [mq:37,bq:0,sd:32] *   M1RP_ID23_RP8
#
#                            VAF   DP  MQ   sign    ALT
# RUNX1_chr21_34892926_G/A  25.4  138  28  False   35.0
# RUNX1_chr21_34892926_G/A  36.2  489  40  False  177.0
# RUNX1_chr21_34892926_G/A  31.2  349  38   True  109.0
# RUNX1_chr21_34892926_G/A  26.3  433  38   True  114.0
# RUNX1_chr21_34892926_G/A  32.9  277  37   True   91.0
# PIK3CA_chr3_179210192_T/C
#                                                        info        sampleID  \
# PIK3CA_chr3_179210192_T/C  17.8% (404) [mq:40,bq:0,sd:30] *  M1RP_ID23_RP10
# PIK3CA_chr3_179210192_T/C  31.5% (143) [mq:34,bq:0,sd:31] *   M1RP_ID23_RP9
#
#                             VAF   DP  MQ  sign   ALT
# PIK3CA_chr3_179210192_T/C  17.8  404  40  True  72.0
# PIK3CA_chr3_179210192_T/C  31.5  143  34  True  45.0

# %%
print(len(set(patinfo_filt_ID23.index[patinfo_filt_ID23["sampleID"]=="M1RP_ID23_RP4"]).intersection(
    patinfo_filt_ID23.index[patinfo_filt_ID23["sampleID"]=="M1RP_ID23_MLN1"])), 
      len(set(patinfo_filt_ID23.index[patinfo_filt_ID23["sampleID"]=="M1RP_ID23_RP9"]).intersection(
    patinfo_filt_ID23.index[patinfo_filt_ID23["sampleID"]=="M1RP_ID23_MLN1"])))
# Out:
# 0 0

# %%
patinfo_filt_ID26 = patinfo_filt_ID26[patinfo_filt_ID26["sampleID"].isin(['M1RP_ID26_MLN1', 'M1RP_ID26_RP3', 
                                                                          'M1RP_ID26_RP1'])]
for x in patinfo_filt_ID26.index.value_counts().reset_index()["index"]:
    print(x)
    print(patinfo_filt_ID26.loc[x])
# Out:
# APC_chr5_112840254_G/GA
#                                                      info        sampleID  \
# APC_chr5_112840254_G/GA   13.2% (76) [mq:26,bq:0,sd:23] *  M1RP_ID26_MLN1
# APC_chr5_112840254_G/GA  37.5% (309) [mq:22,bq:0,sd:29] *   M1RP_ID26_RP3
#
#                           VAF   DP  MQ  sign    ALT
# APC_chr5_112840254_G/GA  13.2   76  26  True   10.0
# APC_chr5_112840254_G/GA  37.5  309  22  True  116.0
# HSD3B1_chr1_119507798_T/G
#                                                        info       sampleID  \
# HSD3B1_chr1_119507798_T/G  29.1% (141) [mq:38,bq:0,sd:32] *  M1RP_ID26_RP1
# HSD3B1_chr1_119507798_T/G    42.0% (150) [mq:26,bq:0,sd:25]  M1RP_ID26_RP3
#
#                             VAF   DP  MQ   sign   ALT
# HSD3B1_chr1_119507798_T/G  29.1  141  38   True  41.0
# HSD3B1_chr1_119507798_T/G  42.0  150  26  False  63.0
# ATM;C11orf65_chr11_108326004_G/T
# info        13.8% (58) [mq:42,bq:0,sd:43]
# sampleID                    M1RP_ID26_RP1
# VAF                                  13.8
# DP                                     58
# MQ                                     42
# sign                                False
# ALT                                   8.0
# Name: ATM;C11orf65_chr11_108326004_G/T, dtype: object
# PIK3CB_chr3_138737877_T/C
# info        11.2% (187) [mq:22,bq:0,sd:29] *
# sampleID                       M1RP_ID26_RP3
# VAF                                     11.2
# DP                                       187
# MQ                                        22
# sign                                    True
# ALT                                     21.0
# Name: PIK3CB_chr3_138737877_T/C, dtype: object

# %%
print(len(set(patinfo_filt_ID26.index[patinfo_filt_ID26["sampleID"]=="M1RP_ID26_RP1"]).intersection(
    patinfo_filt_ID26.index[patinfo_filt_ID26["sampleID"]=="M1RP_ID26_MLN1"])), 
      len(set(patinfo_filt_ID26.index[patinfo_filt_ID26["sampleID"]=="M1RP_ID26_RP3"]).intersection(
    patinfo_filt_ID26.index[patinfo_filt_ID26["sampleID"]=="M1RP_ID26_MLN1"])))
# Out:
# 0 1

# %%
patinfo_filt_ID33 = patinfo_filt_ID33[patinfo_filt_ID33["sampleID"].isin(['M1RP_ID33_MLN5', 'M1RP_ID33_RP5',
                                                                         'M1RP_ID33_RP6', 'M1RP_ID33_RP9'])]
for x in patinfo_filt_ID33.index.value_counts().reset_index()["index"]:
    print(patinfo_filt_ID33.loc[x])
# Out:
#                                                      info        sampleID  \
# MSH6_chr2_47783976_G/A    34.5% (1717) [mq:41,bq:0,sd:29]  M1RP_ID33_MLN5
# MSH6_chr2_47783976_G/A  20.0% (1621) [mq:41,bq:0,sd:30] *   M1RP_ID33_RP5
# MSH6_chr2_47783976_G/A    39.8% (1620) [mq:40,bq:0,sd:27]   M1RP_ID33_RP6
# MSH6_chr2_47783976_G/A  10.1% (1458) [mq:40,bq:0,sd:32] *   M1RP_ID33_RP9
#
#                          VAF    DP  MQ   sign    ALT
# MSH6_chr2_47783976_G/A  34.5  1717  41  False  592.0
# MSH6_chr2_47783976_G/A  20.0  1621  41   True  324.0
# MSH6_chr2_47783976_G/A  39.8  1620  40  False  645.0
# MSH6_chr2_47783976_G/A  10.1  1458  40   True  147.0
#                                                       info        sampleID  \
# BRCA2_chr13_32332719_T/A  37.6% (433) [mq:34,bq:0,sd:28] *  M1RP_ID33_MLN5
# BRCA2_chr13_32332719_T/A  24.3% (424) [mq:39,bq:0,sd:30] *   M1RP_ID33_RP5
# BRCA2_chr13_32332719_T/A  39.6% (359) [mq:38,bq:0,sd:24] *   M1RP_ID33_RP6
# BRCA2_chr13_32332719_T/A  29.5% (457) [mq:34,bq:0,sd:28] *   M1RP_ID33_RP9
#
#                            VAF   DP  MQ  sign    ALT
# BRCA2_chr13_32332719_T/A  37.6  433  34  True  163.0
# BRCA2_chr13_32332719_T/A  24.3  424  39  True  103.0
# BRCA2_chr13_32332719_T/A  39.6  359  38  True  142.0
# BRCA2_chr13_32332719_T/A  29.5  457  34  True  135.0
#                                                       info        sampleID  \
# RNF43_chr17_58371034_C/A  24.6% (798) [mq:41,bq:0,sd:30] *  M1RP_ID33_MLN5
# RNF43_chr17_58371034_C/A  38.9% (935) [mq:41,bq:0,sd:28] *   M1RP_ID33_RP6
#
#                            VAF   DP  MQ  sign    ALT
# RNF43_chr17_58371034_C/A  24.6  798  41  True  196.0
# RNF43_chr17_58371034_C/A  38.9  935  41  True  364.0
# info        13.6% (1049) [mq:41,bq:0,sd:27] *
# sampleID                        M1RP_ID33_RP5
# VAF                                      13.6
# DP                                       1049
# MQ                                         41
# sign                                     True
# ALT                                     143.0
# Name: TP53_chr17_7673700_C/A, dtype: object

# %%
print(len(set(patinfo_filt_ID33.index[patinfo_filt_ID33["sampleID"]=="M1RP_ID33_RP5"]).intersection(
    patinfo_filt_ID33.index[patinfo_filt_ID33["sampleID"]=="M1RP_ID33_MLN5"])), 
      len(set(patinfo_filt_ID33.index[patinfo_filt_ID33["sampleID"]=="M1RP_ID33_RP6"]).intersection(
    patinfo_filt_ID33.index[patinfo_filt_ID33["sampleID"]=="M1RP_ID33_MLN5"])),
     len(set(patinfo_filt_ID33.index[patinfo_filt_ID33["sampleID"]=="M1RP_ID33_RP9"]).intersection(
    patinfo_filt_ID33.index[patinfo_filt_ID33["sampleID"]=="M1RP_ID33_MLN5"])))
# Out:
# 2 3 2

# %%
# Merge all filtered patient information into a single DataFrame
targetedDNA = pd.concat([patinfo_filt_ID3, patinfo_filt_ID4, patinfo_filt_ID8, patinfo_filt_ID23, patinfo_filt_ID26, patinfo_filt_ID33])

variant_info = {
    "chrom": [],
    "pos": [], 
    "genes": [],
    "ref": [],
    "alt": []
}

for info in targetedDNA.index:
    if pd.isna(info):
        variant_info["chrom"].append(float('nan'))
        variant_info["pos"].append(float('nan'))
        variant_info["genes"].append(float('nan'))
        variant_info["ref"].append(float('nan'))
        variant_info["alt"].append(float('nan'))

    else:
        gene, chrom, pos, alts = info.split("_")
        ref, alt = alts.split("/")
        variant_info["chrom"].append(chrom[3:])
        variant_info["pos"].append(pos)
        variant_info["genes"].append(gene)
        variant_info["ref"].append(ref)
        variant_info["alt"].append(alt)

targetedDNA["chrom"] = variant_info["chrom"]
targetedDNA["pos"] = variant_info["pos"]
targetedDNA["genes"] = variant_info["genes"]
targetedDNA["ref"] = variant_info["ref"]
targetedDNA["alt"] = variant_info["alt"]

targetedDNA["Patient ID"] = ["M1RP-"+sample_id.split("_")[1] for sample_id in targetedDNA["sampleID"]]
targetedDNA["Sample ID"] = targetedDNA["sampleID"]

# %%
columns = ["Patient ID", "Sample ID", "chrom", "pos", "genes", "ref", "alt", "VAF", "DP", "MQ", "ALT"]
targetedDNA[columns].to_csv(os.path.join(PATH_DATA, "tNGS_de_novo_variant_calling.csv"), index=False)
